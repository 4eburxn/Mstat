# %% [markdown]
# # Т5

# %%
from numba import jit

import numpy as np
import matplotlib.pyplot as plt

# %%
tet = 50
n = 100

# %%
X = np.random.uniform(tet, tet*2, n)
print("Отсортированный:\n",np.sort(X))
# Out:
# Отсортированный:
#  [51.01008429 51.12497717 51.57658013 52.24126014 52.41594249 52.77766603
#  53.49559077 53.90823516 54.09650652 54.36824376 54.59652827 54.89995721
#  55.51215894 56.4268883  56.59157468 56.93225772 57.07813697 57.09693718
#  57.95587604 58.23949547 59.39297409 59.96472831 59.99742732 60.13603458
#  60.37766212 61.5780951  61.95548742 62.25361232 63.16184645 64.2126113
#  65.63394723 67.80013564 68.59274727 69.16665008 69.80005741 69.97259309
#  70.01427945 71.88559171 72.01604589 72.6712907  72.92771718 72.98701301
#  73.12855308 73.29385036 73.51230066 73.81330449 74.29381747 75.30332551
#  75.91695571 76.3911386  76.65004927 77.1659291  78.03269618 78.25645479
#  78.37899769 78.47142241 78.80756235 78.99493553 79.62999091 79.63623237
#  79.70305328 79.95130056 80.94370718 81.06613328 82.20824184 83.57835087
#  84.63657204 84.78739572 85.52436035 85.68298744 85.82974892 85.89671206
#  86.42799826 86.60347492 87.07665183 87.13646897 87.19859249 87.48956489
#  87.72222782 87.77844892 88.11986718 88.533103   89.12092429 89.27587942
#  89.40335334 89.55512104 90.19444568 90.60563757 91.27769342 91.9954643
#  92.32002958 92.66240763 93.02379957 93.41430629 93.52197108 94.16576624
#  94.27515071 95.68689442 97.47476662 99.54132312]

# %%
b = 0.95

right = np.max(X)/(1+ ((1-b)/2)**(1/n) )
left = np.max(X)/(1+ ((1+b)/2)**(1/n) )
print(f"Точный интервал: ({left}, {right}),\nt2-t1 = {right-left}")
# Out:
# Точный интервал: (49.776961980258996, 50.68854732966397),
# t2-t1 = 0.911585349404973

# %%
a1 = (np.sum(X)/n)
a2 = np.sum(X**2)/n

left1 =  (2 / 3) * (-1.96*np.sqrt((a2 - a1**2)/n) +a1)
right1 = (2 / 3) * ( 1.96*np.sqrt((a2 - a1**2)/n) +a1)
print(f"Асимптотический интервал: ({left1}, {right1}),\nt2-t1 = {right1-left1}")
# Out:
# Асимптотический интервал: (48.001167159042446, 51.59791094113744),
# t2-t1 = 3.596743782094997

# %%
N = 100000
t1 = int(N*0.025)-1
t2 = N-t1

@jit(nopython=True, parallel=True)
def bs(N):
    data = []
    for i in range(100000):
        data.append(2 / 3 * np.mean(np.random.choice(X, size = len(X))))
    return np.sort(data)

data = bs(N)

left2 = 2 / 3 * np.mean(X) + data[t1] - 2 / 3 * np.mean(X)
right2 = 2 / 3 * np.mean(X) + data[t2] - 2 / 3 * np.mean(X)

print(f"Интервал через бутстрап: ({left2}, {right2}),\nt2-t1 = {right2-left2}")
# Out:
# Интервал через бутстрап: (47.98489792491519, 51.57426945867448),
# t2-t1 = 3.589371533759291

# %%
print(f"Точный интервал:\t\t ({left}, {right}),\t\tt2-t1 = {right-left}")
print(f"Асимптотический интервал:\t ({left1}, {right1}),\t\tt2-t1 = {right1-left1}")
print(f"Интервал через бутстрап:\t ({left2}, {right2}),\t\tt2-t1 = {right2-left2}")
# Out:
# Точный интервал:		 (49.776961980258996, 50.68854732966397),		t2-t1 = 0.911585349404973
# Асимптотический интервал:	 (48.001167159042446, 51.59791094113744),		t2-t1 = 3.596743782094997
# Интервал через бутстрап:	 (47.98489792491519, 51.57426945867448),		t2-t1 = 3.589371533759291

# %% [markdown]
# # Т6

# %%
tet = 2
n = 100
X = np.random.pareto(tet, n)+1
print(X)
# Out:
# [1.58619817 1.28416184 1.32994109 2.40075427 1.02288316 2.14579555
#  1.37857108 1.35914341 1.10889553 7.16946708 1.13623423 1.03088149
#  1.51314819 1.27302638 2.77735285 1.39061114 1.00870224 1.74831572
#  2.00090362 1.14275764 1.22147277 1.14260459 1.56045431 1.82005559
#  1.00824551 1.14641525 1.16271593 1.06870385 1.03190537 1.08935403
#  1.49369563 3.95179607 1.01599079 1.74651018 1.85323847 1.26373697
#  1.10379328 2.77768426 1.02283784 1.49680021 1.33651305 1.04676126
#  1.29534594 1.10401828 1.14400493 2.13441111 2.57954825 4.56876764
#  1.02316065 1.00584609 1.11014719 1.0457141  3.25306017 1.0780821
#  2.25290778 1.19338289 1.01807672 2.61078012 2.18400539 1.148229
#  2.20862777 1.48555873 1.96714009 1.09508175 1.82276864 1.1680529
#  1.03489848 1.07903803 1.26117942 1.10178751 1.01726385 1.67965206
#  1.05388773 1.29065015 1.5270291  1.02039656 1.42121072 1.14111604
#  1.44669505 1.21614815 1.57029238 1.89764746 1.02682336 1.12206689
#  1.37289129 1.19656215 1.65427964 2.89286825 2.38757864 1.37068622
#  2.85435782 1.03633331 2.19243122 4.52651539 1.01250172 1.23093545
#  1.26084034 1.01307086 2.15424187 1.15658979]

# %%
tetT = n/np.sum(np.log(X))

delta = (1.96*np.log(2)*(2**(1/(tetT-1))))/((tetT- 1)*10)
right0 = 2 ** (1 / (tetT -1)) + delta
left0  = 2 ** (1 / (tetT -1)) - delta

print(f"ОМП: θ = {tetT}",
      f"Доверительный размах для медианы: [{left}, {right}]",
      f"Размах для медианы: {right0 - left0}", sep = "\n")
# Out:
# ОМП: θ = 2.5894961568674493
# Доверительный размах для медианы: [49.776961980258996, 50.68854732966397]
# Размах для медианы: 0.2643863934621713

# %%
left1 =  tetT- 1.96*(tetT-1)/np.sqrt(n)
right1 = tetT+ 1.96*(tetT-1)/np.sqrt(n)

print(f"Асимптотический доверительный интервал: ({left0}, {right0})",
      f"Размах: {right1 - left1}", sep = "\n")
# Out:
# Асимптотический доверительный интервал: (1.414439028329197, 1.6788254217913683)
# Размах: 0.6230824934920403

# %%
N = 100000
b=0.95
t1 = int(N*(-b+1)/2)-1
t2 = N-t1

@jit(nopython=True, parallel=True)
def bs2(N):
    data = []
    for i in range(100000):
        data.append(n / np.sum(np.log((np.random.choice(X, size = len(X))))) - tetT)
    return np.sort(data)

data = bs2(N)

left2 = tetT + data[t1]
right2 = tetT + data[t2]

print(f"Непараметрический бутстрап(0.95): ({left2}, {right2})",
      f"Размах: {right2 - left2}", sep="\n")
# Out:
# Непараметрический бутстрап(0.95): (2.1467344170291653, 3.2129427994809925)
# Размах: 1.0662083824518271

# %%
N = 100000
b=0.95
t1 = int(N*(-b+1)/2)-1
t2 = N-t1


def bs2(N):
    data = []
    for i in range(100000):
        data.append( n / np.sum(np.log(np.random.pareto(tet, n)+1)) - tetT)
    return np.sort(data)

data = bs2(N)

left3 = tetT + data[t1]
right3 = tetT + data[t2]
print(f"Параметрический бутстрап(0.95): ({left3}, {right3})",
      f"Размах: {right3 - left3}", sep="\n")
# Out:
# Параметрический бутстрап(0.95): (1.6605209581675309, 2.4575482781923492)
# Размах: 0.7970273200248184

# %%
print(f"Асимптотический интервал: \t\t({left0}, {right0})\t\t",
      f"Размах: {right1 - left1}", sep = "\t")
print(f"Непараметрический бутстрап(0.95): \t({left2}, {right2})\t",
      f"Размах: {right2 - left2}", sep="\t")
print(f"Параметрический бутстрап(0.95): \t({left3}, {right3})\t",
      f"Размах: {right3 - left3}", sep="\t")
# Out:
# Асимптотический интервал: 		(1.414439028329197, 1.6788254217913683)			Размах: 0.6230824934920403
# Непараметрический бутстрап(0.95): 	(2.1467344170291653, 3.2129427994809925)		Размах: 1.0662083824518271
# Параметрический бутстрап(0.95): 	(1.6605209581675309, 2.4575482781923492)		Размах: 0.7970273200248184
